# %% [markdown]
# # Part 1

# %%
import datetime
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# %%
dtype = {
    "ID": str,
    "age": str,
    "sex": str,
    "city": str,
    "province": str,
    "country": str,
    "latitude": float,
    "longitude": float,
    "geo_resolution": str,
    "date_onset_symptoms": str,
    "date_admission_hospital": str,
    "date_confirmation": str,
    "symptoms": str,
    "lives_in_Wuhan": str,
    "travel_history_dates": str,
    "travel_history_location": str,
    "reported_market_exposure": str,
    "additional_information": str,
    "chronic_disease": str,
    "source": str,
    "sequence_available": str,
    "outcome": str,
    "date_death_or_discharge": str,
    "notes_for_discussion": str,
    "location": str,
    "admin1": str,
    "admin2": str,
    "admin3": str,
    "country_new": str,
    "admin_id": float,
    "data_moderator_initials": str,
    "travel_history_binary": str
}

# %%
df: pd.DataFrame = pd.read_csv(
    "./latestdata.csv",
    dtype=dtype,
    # nrows=1000
)
df
# Out:
#                   ID  age     sex            city          province  \
# 0            000-1-1  NaN    male        Shek Lei         Hong Kong
# 1           000-1-10   78    male      Vo Euganeo            Veneto
# 2          000-1-100   61  female             NaN               NaN
# 3         000-1-1000  NaN     NaN  Zhengzhou City             Henan
# 4        000-1-10000  NaN     NaN  Pingxiang City           Jiangxi
# ...              ...  ...     ...             ...               ...
# 2676306    010-99995   52  female        Calleria  Coronel Portillo
# 2676307    010-99996   52  female    Pueblo Libre              Lima
# 2676308    010-99997   52  female           Comas              Lima
# 2676309    010-99998   52    male          Callao            Callao
# 2676310    010-99999   52    male      Los Olivos              Lima
#
#            country   latitude   longitude geo_resolution date_onset_symptoms  \
# 0            China  22.365019  114.133808          point                 NaN
# 1            Italy  45.297748   11.658382          point                 NaN
# 2        Singapore   1.353460  103.815100         admin0                 NaN
# 3            China  34.629310  113.468000         admin2                 NaN
# 4            China  27.513560  113.902900         admin2                 NaN
# ...            ...        ...         ...            ...                 ...
# 2676306       Peru  -8.378190  -74.539700          point                 NaN
# 2676307       Peru -12.076530  -77.067350          point                 NaN
# 2676308       Peru -11.932980  -77.040850          point                 NaN
# 2676309       Peru -12.000740  -77.118240          point                 NaN
# 2676310       Peru -11.976260  -77.075030          point                 NaN
#
#          ... date_death_or_discharge notes_for_discussion     location admin3  \
# 0        ...                     NaN                  NaN     Shek Lei    NaN
# 1        ...              22.02.2020                  NaN  Vo' Euganeo    NaN
# 2        ...              17.02.2020                  NaN          NaN    NaN
# 3        ...                     NaN                  NaN          NaN    NaN
# 4        ...                     NaN                  NaN          NaN    NaN
# ...      ...                     ...                  ...          ...    ...
# 2676306  ...                     NaN                  NaN          NaN    NaN
# 2676307  ...                     NaN                  NaN          NaN    NaN
# 2676308  ...                     NaN                  NaN          NaN    NaN
# 2676309  ...                     NaN                  NaN          NaN    NaN
# 2676310  ...                     NaN                  NaN          NaN    NaN
#
#                  admin2     admin1 country_new admin_id  \
# 0                   NaN  Hong Kong       China   8029.0
# 1                   NaN     Veneto       Italy   8954.0
# 2                   NaN        NaN   Singapore    200.0
# 3        Zhengzhou City      Henan       China  10091.0
# 4        Pingxiang City    Jiangxi       China   7060.0
# ...                 ...        ...         ...      ...
# 2676306             NaN        NaN        Peru  14429.0
# 2676307             NaN        NaN        Peru  14695.0
# 2676308             NaN        NaN        Peru  14400.0
# 2676309             NaN        NaN        Peru  14516.0
# 2676310             NaN        NaN        Peru  14502.0
#
#          data_moderator_initials travel_history_binary
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# ...                          ...                   ...
# 2676306                      NaN                 False
# 2676307                      NaN                 False
# 2676308                      NaN                 False
# 2676309                      NaN                 False
# 2676310                      NaN                 False
#
# [2676311 rows x 33 columns]

# %%
df.info(verbose=True, max_cols=307382, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676311 entries, 0 to 2676310
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   ID                        2676311 non-null  object
#  1   age                       578018 non-null   object
#  2   sex                       580157 non-null   object
#  3   city                      1698630 non-null  object
#  4   province                  2223647 non-null  object
#  5   country                   2676196 non-null  object
#  6   latitude                  2676250 non-null  float64
#  7   longitude                 2676250 non-null  float64
#  8   geo_resolution            2676250 non-null  object
#  9   date_onset_symptoms       261599 non-null   object
#  10  date_admission_hospital   116211 non-null   object
#  11  date_confirmation         2567822 non-null  object
#  12  symptoms                  2052 non-null     object
#  13  lives_in_Wuhan            4338 non-null     object
#  14  travel_history_dates      2611 non-null     object
#  15  travel_history_location   9222 non-null     object
#  16  reported_market_exposure  1069 non-null     object
#  17  additional_information    45855 non-null    object
#  18  chronic_disease_binary    2676311 non-null  bool
#  19  chronic_disease           215 non-null      object
#  20  source                    2109347 non-null  object
#  21  sequence_available        12 non-null       object
#  22  outcome                   307382 non-null   object
#  23  date_death_or_discharge   3148 non-null     object
#  24  notes_for_discussion      640 non-null      object
#  25  location                  13376 non-null    object
#  26  admin3                    80434 non-null    object
#  27  admin2                    826054 non-null   object
#  28  admin1                    1257558 non-null  object
#  29  country_new               2645758 non-null  object
#  30  admin_id                  2676250 non-null  float64
#  31  data_moderator_initials   1742983 non-null  object
#  32  travel_history_binary     2610732 non-null  object
# dtypes: bool(1), float64(3), object(29)
# memory usage: 655.9+ MB

# %%
# Total of missing values
total_cells = np.prod(df.shape)
total_missing = df.isnull().sum().sum()
# Percentage of missing data
print((total_missing / total_cells) * 100)
# Out:
# 56.49519511043826

# %%
df = df.drop('latitude', axis=1)

# %%
df = df.drop('longitude', axis=1)

# %%
df = df.drop('ID', axis=1)

# %%
df = df.drop('data_moderator_initials', axis=1)

# %%
df = df.drop('source', axis=1)

# %%
df = df.drop('notes_for_discussion', axis=1)

# %%
df = df.drop('sequence_available', axis=1)

# %%
df = df.drop('additional_information', axis=1)

# %%
for col in df:
    if df.dtypes[col] == "object":
        df[col] = df[col].str.lower()

# %%
df["outcome"].value_counts()
# Out:
# outcome
# hospitalized                                                                202475
# recovered                                                                    97315
# deceased                                                                      5011
# died                                                                           920
# under treatment                                                                370
# receiving treatment                                                            257
# alive                                                                          189
# stable                                                                         187
# discharge                                                                      175
# stable condition                                                               133
# https://www.mspbs.gov.py/covid-19.php                                          126
# discharged                                                                     119
# death                                                                           52
# dead                                                                            16
# migrated_other                                                                   8
# migrated                                                                         5
# discharged from hospital                                                         4
# released from quarantine                                                         4
# critical condition                                                               2
# critical condition, intubated as of 14.02.2020                                   2
# treated in an intensive care unit (14.02.2020)                                   2
# severe                                                                           2
# recovering at home 03.03.2020                                                    2
# not hospitalized                                                                 2
# symptoms only improved with cough. currently hospitalized for follow-up.         2
# severe illness                                                                   1
# unstable                                                                         1
# Name: count, dtype: int64

# %%
def parse_outcome(outcome):
    if isinstance(outcome, float):
        return "recovered"
    else:
        dead = ["died", "deceased", "death", "dead"]
        hospital = ["receiving treatment", "under treatment", "hospitalized",
                    "symptoms only improved with cough. currently hospitalized for follow-up.",
                    "treated in an intensive care unit (14.02.2020)", "stable condition", "stable",
                    "critical condition, intubated as of 14.02.2020", "severe", "critical condition", "severe illness",
                    "unstable", "migrated", "migrated_other"]
        recovered = ["alive", "discharge", "discharged from hospital", "recovering at home 03.03.2020",
                     "not hospitalized", "released from quarantine", "https://www.mspbs.gov.py/covid-19.php",
                     "discharged"]

        if outcome in dead:
            return "death"
        if outcome in hospital:
            return "hospitalized"
        if outcome in recovered:
            return "recovered"
    return outcome


df["outcome"].apply(parse_outcome).value_counts()
# Out:
# outcome
# recovered       2466865
# hospitalized     203447
# death              5999
# Name: count, dtype: int64

# %%
df["outcome"] = df["outcome"].apply(parse_outcome)

# %%
# df["sex"] = df["sex"].fillna(df["sex"].mode()[0])

# %%
df["country"] = df["country"].fillna(df["country"].mode()[0])

# %%
def get_province(row):
    if row["province"].value_counts().empty:
        return float('NaN')
    else:
        return row["province"].value_counts().idxmax()


df["province"] = df["province"].fillna(df.groupby('country').apply(get_province, include_groups=False))

# %%
# Clean age field
def age_to_int(age_str):
    if isinstance(age_str, float):
        return None

    if "-" in age_str:
        age_min, age_max = age_str.split("-")
        if age_min == '':
            return int(age_max)
        if age_max == '':
            return int(age_min)
        age_min, age_max = int(age_min), int(age_max)
        return int((age_min + age_max) / 2)

    if "weeks" in age_str:
        return 0

    if "months" in age_str or "month" in age_str:
        num, _ = age_str.split(" ")
        if int(num) < 12:
            return 0
        return int(int(num) / 12)

    if age_str[-1] == "+" or age_str[-1] == "-":
        return int(age_str[:-1])

    return int(float(age_str))


df["age"] = df["age"].apply(age_to_int)
df["age"] = df["age"].fillna(int(df["age"].mean()))

# %%
def parse_bool(x):
    return not isinstance(x, float)

# %%
df["chronic_disease_binary"] = df["chronic_disease_binary"].apply(parse_bool)

# %%
df["asymptomatic"] = df["date_onset_symptoms"].apply(parse_bool)

# %%
df["lives_in_Wuhan"] = df["lives_in_Wuhan"].apply(parse_bool)

# %%
df["travel_history_binary"] = df["travel_history_binary"].apply(parse_bool)

# %%
df["reported_market_exposure"] = df["reported_market_exposure"].apply(parse_bool)

# %%
df.info(verbose=True, max_cols=307382, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676311 entries, 0 to 2676310
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   age                       2676311 non-null  float64
#  1   sex                       580157 non-null   object
#  2   city                      1698630 non-null  object
#  3   province                  2223647 non-null  object
#  4   country                   2676311 non-null  object
#  5   geo_resolution            2676250 non-null  object
#  6   date_onset_symptoms       261599 non-null   object
#  7   date_admission_hospital   116211 non-null   object
#  8   date_confirmation         2567822 non-null  object
#  9   symptoms                  2052 non-null     object
#  10  lives_in_Wuhan            2676311 non-null  bool
#  11  travel_history_dates      2611 non-null     object
#  12  travel_history_location   9222 non-null     object
#  13  reported_market_exposure  2676311 non-null  bool
#  14  chronic_disease_binary    2676311 non-null  bool
#  15  chronic_disease           215 non-null      object
#  16  outcome                   2676311 non-null  object
#  17  date_death_or_discharge   3148 non-null     object
#  18  location                  13376 non-null    object
#  19  admin3                    80434 non-null    object
#  20  admin2                    826054 non-null   object
#  21  admin1                    1257558 non-null  object
#  22  country_new               2645758 non-null  object
#  23  admin_id                  2676250 non-null  float64
#  24  travel_history_binary     2676311 non-null  bool
#  25  asymptomatic              2676311 non-null  bool
# dtypes: bool(5), float64(2), object(19)
# memory usage: 441.6+ MB

# %%
df
# Out:
#           age     sex            city          province    country  \
# 0        45.0    male        shek lei         hong kong      china
# 1        78.0    male      vo euganeo            veneto      italy
# 2        61.0  female             NaN               NaN  singapore
# 3        45.0     NaN  zhengzhou city             henan      china
# 4        45.0     NaN  pingxiang city           jiangxi      china
# ...       ...     ...             ...               ...        ...
# 2676306  52.0  female        calleria  coronel portillo       peru
# 2676307  52.0  female    pueblo libre              lima       peru
# 2676308  52.0  female           comas              lima       peru
# 2676309  52.0    male          callao            callao       peru
# 2676310  52.0    male      los olivos              lima       peru
#
#         geo_resolution date_onset_symptoms date_admission_hospital  \
# 0                point                 NaN                     NaN
# 1                point                 NaN                     NaN
# 2               admin0                 NaN                     NaN
# 3               admin2                 NaN                     NaN
# 4               admin2                 NaN                     NaN
# ...                ...                 ...                     ...
# 2676306          point                 NaN                     NaN
# 2676307          point                 NaN                     NaN
# 2676308          point                 NaN                     NaN
# 2676309          point                 NaN                     NaN
# 2676310          point                 NaN                     NaN
#
#         date_confirmation symptoms  ...       outcome date_death_or_discharge  \
# 0              14.02.2020      NaN  ...  hospitalized                     NaN
# 1              21.02.2020      NaN  ...         death              22.02.2020
# 2              14.02.2020      NaN  ...     recovered              17.02.2020
# 3              26.01.2020      NaN  ...     recovered                     NaN
# 4              14.02.2020      NaN  ...     recovered                     NaN
# ...                   ...      ...  ...           ...                     ...
# 2676306        17.05.2020      NaN  ...     recovered                     NaN
# 2676307        17.05.2020      NaN  ...     recovered                     NaN
# 2676308        17.05.2020      NaN  ...     recovered                     NaN
# 2676309        17.05.2020      NaN  ...     recovered                     NaN
# 2676310        17.05.2020      NaN  ...     recovered                     NaN
#
#             location  admin3          admin2     admin1 country_new admin_id  \
# 0           shek lei     NaN             NaN  hong kong       china   8029.0
# 1        vo' euganeo     NaN             NaN     veneto       italy   8954.0
# 2                NaN     NaN             NaN        NaN   singapore    200.0
# 3                NaN     NaN  zhengzhou city      henan       china  10091.0
# 4                NaN     NaN  pingxiang city    jiangxi       china   7060.0
# ...              ...     ...             ...        ...         ...      ...
# 2676306          NaN     NaN             NaN        NaN        peru  14429.0
# 2676307          NaN     NaN             NaN        NaN        peru  14695.0
# 2676308          NaN     NaN             NaN        NaN        peru  14400.0
# 2676309          NaN     NaN             NaN        NaN        peru  14516.0
# 2676310          NaN     NaN             NaN        NaN        peru  14502.0
#
#         travel_history_binary asymptomatic
# 0                       False        False
# 1                       False        False
# 2                       False        False
# 3                       False        False
# 4                       False        False
# ...                       ...          ...
# 2676306                  True        False
# 2676307                  True        False
# 2676308                  True        False
# 2676309                  True        False
# 2676310                  True        False
#
# [2676311 rows x 26 columns]

# %%
df['date_confirmation'] = pd.to_datetime(df['date_confirmation'], format='%d.%m.%Y', errors='coerce')

# %%
df['days_since_subject_zero'] = df["date_confirmation"].apply(lambda d: (d - datetime.datetime.strptime("17.11.2019", '%d.%m.%Y')).days)

# %%
for col in df:
    print(df[col].value_counts())
# Out:
# age
# 45.0     2105146
# 47.0       79415
# 24.0       56325
# 69.0       35429
# 80.0       21346
#           ...
# 103.0          4
# 120.0          4
# 121.0          1
# 107.0          1
# 106.0          1
# Name: count, Length: 110, dtype: int64
# sex
# male      307188
# female    272969
# Name: count, dtype: int64
# city
# moscow                149478
# mumbai                 56178
# moscow oblast          29170
# chennai                23907
# milano                 23124
#                        ...
# mogpog                     1
# palayan                    1
# labangan                   1
# sampaloc                   1
# san pedro de coris         1
# Name: count, Length: 8335, dtype: int64
# province
# central                        206921
# england                        156106
# maharashtra                    106515
# lima                            99326
# lombardia                       87238
#                                 ...
# laghouat                            1
# san andres islas                    1
# thessaly and central greece         1
# hoguin                              1
# tarata                              1
# Name: count, Length: 1210, dtype: int64
# country
# india                               301322
# russia                              299568
# united kingdom                      299469
# spain                               255108
# italy                               231006
#                                      ...
# latvia                                   1
# gibraltar                                1
# liechtenstein                            1
# saint vincent and the grenadines         1
# andorra                                  1
# Name: count, Length: 146, dtype: int64
# geo_resolution
# point     971106
# admin2    776053
# admin0    450641
# admin1    398033
# admin3     80341
# jpcp          76
# Name: count, dtype: int64
# date_onset_symptoms
# 20.03.2020    6735
# 23.03.2020    6436
# 16.03.2020    6336
# 27.03.2020    6191
# 18.03.2020    6095
#               ...
# 30.12.2019       1
# 26.11.2020       1
# 23.12.2019       1
# 20.12.2019       1
# 08.06.2020       1
# Name: count, Length: 170, dtype: int64
# date_admission_hospital
# 01.04.2020    4784
# 02.04.2020    4534
# 31.03.2020    4204
# 03.04.2020    4176
# 07.04.2020    3647
#               ...
# 16.02.2020       2
# 31.12.2019       2
# 01.01.2020       1
# 10.12.2019       1
# 06.01.2020       1
# Name: count, Length: 162, dtype: int64
# date_confirmation
# 2020-03-26    48319
# 2020-03-27    43379
# 2020-03-23    39288
# 2020-05-06    38679
# 2020-05-07    38606
#               ...
# 2020-01-12        2
# 2020-01-17        2
# 2020-01-15        2
# 2020-01-06        2
# 2020-01-16        2
# Name: count, Length: 156, dtype: int64
# symptoms
# fever                                    320
# mild to moderate                         257
# mild:moderate                            128
# cough, fever                             126
# cough                                     52
#                                         ...
# fatigue, shortness of breath               1
# chest distress, cough, fatigue, fever      1
# cold chills, muscular soreness             1
# cough, expectoration, emesis, fever        1
# kidney failure                             1
# Name: count, Length: 435, dtype: int64
# lives_in_Wuhan
# False    2671973
# True        4338
# Name: count, dtype: int64
# travel_history_dates
# 21.01.2020               114
# 22.01.2020                99
# 15.03.2020                97
# 14.03.2020                92
# 20.01.2020                88
#                         ...
# 01.04.2020                 1
# 03.04.2020                 1
# 17.03.2020-19.03.2020      1
# 03.03.2020-08.03.2020      1
# 29.04.2020                 1
# Name: count, Length: 214, dtype: int64
# travel_history_location
# usa                               1234
# spain                             1149
# wuhan city, hubei                  729
# italy                              684
# france                             340
#                                   ...
# cambodia                             1
# south korea; united states           1
# united arab emirates; thailand       1
# thailand; singapore                  1
# uruguay                              1
# Name: count, Length: 741, dtype: int64
# reported_market_exposure
# False    2675242
# True        1069
# Name: count, dtype: int64
# chronic_disease_binary
# True    2676311
# Name: count, dtype: int64
# chronic_disease
# https://coronavirus.dc.gov/page/coronavirus-data                                    48
# hypertension                                                                        22
# https://cv.nmhealth.org/2020/03/25/updated-new-mexico-covid-19-cases-now-at-112/    12
# hypertension:diabetes                                                               10
# diabetes                                                                             9
#                                                                                     ..
# chronic kidney disease:hypertension:diabetes:ischemic heart disease                  1
# pre-renal azotemia:diabetes:hypertension                                             1
# benign prostatic hyperplasia                                                         1
# hypertension:bronchial asthma:impaired fasting glucose                               1
# diabetes:hypertenstion:upper git bleeding                                            1
# Name: count, Length: 81, dtype: int64
# outcome
# recovered       2466865
# hospitalized     203447
# death              5999
# Name: count, dtype: int64
# date_death_or_discharge
# 30.05.2020    55
# 22.05.2020    55
# 03.06.2020    54
# 29.05.2020    50
# 26.05.2020    50
#               ..
# 31.01.2020     2
# 03.22.2020     1
# 19.01.2020     1
# 09.01.2020     1
# 18.01.2020     1
# Name: count, Length: 144, dtype: int64
# location
# jaipur               3545
# agra                 1661
# gurugram             1171
# chicago               985
# yokohama port         958
#                      ...
# cuxhaven district       1
# middle franconia        1
# fuerstenfeldbruck       1
# hannover region         1
# bordeaux                1
# Name: count, Length: 342, dtype: int64
# admin3
# birmingham          3160
# sheffield           2245
# leeds               1617
# manchester          1380
# liverpool           1339
#                     ...
# wangjiang county       2
# westoverledingen       1
# schuettorf             1
# uetze                  1
# yuan'an county         1
# Name: count, Length: 409, dtype: int64
# admin2
# moscow            149476
# moscow oblast      29170
# milano             23124
# greater london     22574
# torino             15688
#                    ...
# barry county           1
# allegan county         1
# gila county            1
# macon county           1
# ravalli county         1
# Name: count, Length: 2085, dtype: int64
# admin1
# central                         200911
# england                         147694
# lombardia                        78348
# madrid                           57756
# new york                         56468
#                                  ...
# bruxelles-capitale                   1
# obwalden                             1
# lucerne                              1
# bajia                                1
# santiago metropolitan region         1
# Name: count, Length: 615, dtype: int64
# country_new
# india                               301207
# russia                              299568
# united kingdom                      299469
# spain                               255108
# italy                               231006
#                                      ...
# gibraltar                                1
# liechtenstein                            1
# saint vincent and the grenadines         1
# andorra                                  1
# gambia                                   1
# Name: count, Length: 145, dtype: int64
# admin_id
# 228.0      159779
# 6345.0     149476
# 235.0      107767
# 577.0       57756
# 10966.0     56178
#             ...
# 13256.0         1
# 13254.0         1
# 13250.0         1
# 13248.0         1
# 15118.0         1
# Name: count, Length: 10108, dtype: int64
# travel_history_binary
# True     2610732
# False      65579
# Name: count, dtype: int64
# asymptomatic
# False    2414712
# True      261599
# Name: count, dtype: int64
# days_since_subject_zero
# 130.0    48319
# 131.0    43379
# 127.0    39288
# 171.0    38679
# 172.0    38606
#          ...
# 56.0         2
# 61.0         2
# 59.0         2
# 50.0         2
# 60.0         2
# Name: count, Length: 156, dtype: int64

# %%
def is_correlated(var_name1, var_name2, data_frame: pd.DataFrame):
    try:
        new_frame = data_frame[[var_name1, var_name2]]
        new_frame = new_frame.dropna(how="any", axis=0)
        ct = pd.crosstab(index=new_frame[var_name1], columns=new_frame[var_name2])
        print(ct)
        chi2_res = chi2_contingency(ct, )
        p, x, dof_ = chi2_res[1], "correlated" if chi2_res[1] < 0.05 else "not-correlated", chi2_res[2]
        return p, x, dof_
    except ValueError:
        return 0, "no data", 0

# %%
outcome_df = df[df['outcome'].notna()]

# %%
corr = [[], []]
to_check = ["sex", "country", "age", "lives_in_Wuhan", "travel_history_binary"]
for var1 in df:
    if var1 != "ID" and var1 in to_check:
        p_val, correlation, dof = is_correlated(var1, "outcome", outcome_df)
        if correlation == "correlated":
            corr[0].append((p_val, dof, var1))
        else:
            corr[1].append((p_val, dof, var1))
        print("")

corr[0].sort()
corr[1].sort()

print("Correlated")

for ln in corr[0]:
    print(ln)

print("Non-Correlated")

for ln in corr[1]:
    print(ln)
# Out:
# outcome  death  hospitalized  recovered
# sex
# female     546         10788     261635
# male       941         20586     285661
#
# outcome               death  hospitalized  recovered
# country
# afghanistan               0             0          8
# albania                   0             0       1054
# algeria                   7             0       1260
# andorra                   0             0          1
# angola                    0             0          4
# ...                     ...           ...        ...
# venezuela                 0             0          2
# vietnam                   0             0         34
# virgin islands, u.s.      0             0          2
# zambia                    0             0         22
# zimbabwe                  4            31          1
#
# [146 rows x 3 columns]
#
# outcome         death  hospitalized  recovered
# lives_in_Wuhan
# False            5954        203433    2462586
# True               45            14       4279
#
# outcome                death  hospitalized  recovered
# travel_history_binary
# False                     81            82      65416
# True                    5918        203365    2401449
#
# Correlated
# (0.0, 2, 'sex')
# (0.0, 2, 'travel_history_binary')
# (0.0, 290, 'country')
# (1.3254731626810238e-98, 2, 'lives_in_Wuhan')
# Non-Correlated

# %% [markdown]
# # MCA
# Here we will use MCA instead of PCA in order to produce visualizations for discrete variables

# %%
import prince
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
famd_dataset = df[["outcome", "age"]].sample(n=5000, random_state=42)

famd_dataset["outcome"] = famd_dataset["outcome"]

famd_dataset =  famd_dataset.dropna(how="any", axis=0)

# %%
famd_dataset.info(verbose=True, max_cols=307382, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 819466 to 1717615
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   outcome  5000 non-null   object
#  1   age      5000 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 117.2+ KB

# %%
famd = prince.FAMD(
    n_components=1000,
    n_iter=5,
    copy=True,
    check_input=True,
    random_state=42,
    engine="sklearn" # same parameter as sklearn.preprocessing.OneHotEncoder
)
famd = famd.fit(famd_dataset)
famd.eigenvalues_summary
# Out:
# C:\Users\octav\PycharmProjects\ai_project\.venv\Lib\site-packages\prince\pca.py:175: PerformanceWarning: Concatenating sparse arrays with multiple fill values: '[-0.0360555127546399, -0.19493588689617927, -0.6787488489861326]'. Picking the first and converting the rest.
#   X = self.scaler_.transform(X.to_numpy())
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              1.001        50.05%                     50.05%
# 1              0.500        25.00%                     75.05%
# 2              0.499        24.95%                    100.00%
# 3              0.000         0.00%                    100.00%

# %%
famd.plot(
    famd_dataset,
    x_component=0,
    y_component=1,
)
# Out:
# C:\Users\octav\PycharmProjects\ai_project\.venv\Lib\site-packages\prince\pca.py:175: PerformanceWarning: Concatenating sparse arrays with multiple fill values: '[-0.0360555127546399, -0.19493588689617927, -0.6787488489861326]'. Picking the first and converting the rest.
#   X = self.scaler_.transform(X.to_numpy())
# alt.LayerChart(...)

# %%
famd.column_contributions_.head().style.format('{:.0%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_85b43">
#   <thead>
#     <tr>
#       <th class="index_name level0" >component</th>
#       <th id="T_85b43_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_85b43_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_85b43_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_85b43_level0_col3" class="col_heading level0 col3" >3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85b43_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_85b43_row0_col0" class="data row0 col0" >100%</td>
#       <td id="T_85b43_row0_col1" class="data row0 col1" >0%</td>
#       <td id="T_85b43_row0_col2" class="data row0 col2" >0%</td>
#       <td id="T_85b43_row0_col3" class="data row0 col3" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_85b43_level0_row1" class="row_heading level0 row1" >outcome</th>
#       <td id="T_85b43_row1_col0" class="data row1 col0" >0%</td>
#       <td id="T_85b43_row1_col1" class="data row1 col1" >200%</td>
#       <td id="T_85b43_row1_col2" class="data row1 col2" >200%</td>
#       <td id="T_85b43_row1_col3" class="data row1 col3" >2040401607005410474904436038680182784%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #

# %% [markdown]
# # Part 2: Bayes Net

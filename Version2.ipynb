# %% [markdown]
# # Part 1

# %%
import datetime
import numpy as np
import pandas as pd
from scipy.stats import chi2_contingency

# %%
dtype = {
    "ID": str,
    "age": str,
    "sex": str,
    "city": str,
    "province": str,
    "country": str,
    "latitude": float,
    "longitude": float,
    "geo_resolution": str,
    "date_onset_symptoms": str,
    "date_admission_hospital": str,
    "date_confirmation": str,
    "symptoms": str,
    "lives_in_Wuhan": str,
    "travel_history_dates": str,
    "travel_history_location": str,
    "reported_market_exposure": str,
    "additional_information": str,
    "chronic_disease": str,
    "source": str,
    "sequence_available": str,
    "outcome": str,
    "date_death_or_discharge": str,
    "notes_for_discussion": str,
    "location": str,
    "admin1": str,
    "admin2": str,
    "admin3": str,
    "country_new": str,
    "admin_id": float,
    "data_moderator_initials": str,
    "travel_history_binary": str
}

# %%
df: pd.DataFrame = pd.read_csv(
    "./latestdata.csv",
    dtype=dtype,
    # nrows=1000
)
df
# Out:
#                   ID  age     sex            city          province  \
# 0            000-1-1  NaN    male        Shek Lei         Hong Kong
# 1           000-1-10   78    male      Vo Euganeo            Veneto
# 2          000-1-100   61  female             NaN               NaN
# 3         000-1-1000  NaN     NaN  Zhengzhou City             Henan
# 4        000-1-10000  NaN     NaN  Pingxiang City           Jiangxi
# ...              ...  ...     ...             ...               ...
# 2676306    010-99995   52  female        Calleria  Coronel Portillo
# 2676307    010-99996   52  female    Pueblo Libre              Lima
# 2676308    010-99997   52  female           Comas              Lima
# 2676309    010-99998   52    male          Callao            Callao
# 2676310    010-99999   52    male      Los Olivos              Lima
#
#            country   latitude   longitude geo_resolution date_onset_symptoms  \
# 0            China  22.365019  114.133808          point                 NaN
# 1            Italy  45.297748   11.658382          point                 NaN
# 2        Singapore   1.353460  103.815100         admin0                 NaN
# 3            China  34.629310  113.468000         admin2                 NaN
# 4            China  27.513560  113.902900         admin2                 NaN
# ...            ...        ...         ...            ...                 ...
# 2676306       Peru  -8.378190  -74.539700          point                 NaN
# 2676307       Peru -12.076530  -77.067350          point                 NaN
# 2676308       Peru -11.932980  -77.040850          point                 NaN
# 2676309       Peru -12.000740  -77.118240          point                 NaN
# 2676310       Peru -11.976260  -77.075030          point                 NaN
#
#          ... date_death_or_discharge notes_for_discussion     location admin3  \
# 0        ...                     NaN                  NaN     Shek Lei    NaN
# 1        ...              22.02.2020                  NaN  Vo' Euganeo    NaN
# 2        ...              17.02.2020                  NaN          NaN    NaN
# 3        ...                     NaN                  NaN          NaN    NaN
# 4        ...                     NaN                  NaN          NaN    NaN
# ...      ...                     ...                  ...          ...    ...
# 2676306  ...                     NaN                  NaN          NaN    NaN
# 2676307  ...                     NaN                  NaN          NaN    NaN
# 2676308  ...                     NaN                  NaN          NaN    NaN
# 2676309  ...                     NaN                  NaN          NaN    NaN
# 2676310  ...                     NaN                  NaN          NaN    NaN
#
#                  admin2     admin1 country_new admin_id  \
# 0                   NaN  Hong Kong       China   8029.0
# 1                   NaN     Veneto       Italy   8954.0
# 2                   NaN        NaN   Singapore    200.0
# 3        Zhengzhou City      Henan       China  10091.0
# 4        Pingxiang City    Jiangxi       China   7060.0
# ...                 ...        ...         ...      ...
# 2676306             NaN        NaN        Peru  14429.0
# 2676307             NaN        NaN        Peru  14695.0
# 2676308             NaN        NaN        Peru  14400.0
# 2676309             NaN        NaN        Peru  14516.0
# 2676310             NaN        NaN        Peru  14502.0
#
#          data_moderator_initials travel_history_binary
# 0                            NaN                   NaN
# 1                            NaN                   NaN
# 2                            NaN                   NaN
# 3                            NaN                   NaN
# 4                            NaN                   NaN
# ...                          ...                   ...
# 2676306                      NaN                 False
# 2676307                      NaN                 False
# 2676308                      NaN                 False
# 2676309                      NaN                 False
# 2676310                      NaN                 False
#
# [2676311 rows x 33 columns]

# %%
df.info(verbose=True, max_cols=307382, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676311 entries, 0 to 2676310
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   ID                        2676311 non-null  object
#  1   age                       578018 non-null   object
#  2   sex                       580157 non-null   object
#  3   city                      1698630 non-null  object
#  4   province                  2223647 non-null  object
#  5   country                   2676196 non-null  object
#  6   latitude                  2676250 non-null  float64
#  7   longitude                 2676250 non-null  float64
#  8   geo_resolution            2676250 non-null  object
#  9   date_onset_symptoms       261599 non-null   object
#  10  date_admission_hospital   116211 non-null   object
#  11  date_confirmation         2567822 non-null  object
#  12  symptoms                  2052 non-null     object
#  13  lives_in_Wuhan            4338 non-null     object
#  14  travel_history_dates      2611 non-null     object
#  15  travel_history_location   9222 non-null     object
#  16  reported_market_exposure  1069 non-null     object
#  17  additional_information    45855 non-null    object
#  18  chronic_disease_binary    2676311 non-null  bool
#  19  chronic_disease           215 non-null      object
#  20  source                    2109347 non-null  object
#  21  sequence_available        12 non-null       object
#  22  outcome                   307382 non-null   object
#  23  date_death_or_discharge   3148 non-null     object
#  24  notes_for_discussion      640 non-null      object
#  25  location                  13376 non-null    object
#  26  admin3                    80434 non-null    object
#  27  admin2                    826054 non-null   object
#  28  admin1                    1257558 non-null  object
#  29  country_new               2645758 non-null  object
#  30  admin_id                  2676250 non-null  float64
#  31  data_moderator_initials   1742983 non-null  object
#  32  travel_history_binary     2610732 non-null  object
# dtypes: bool(1), float64(3), object(29)
# memory usage: 655.9+ MB

# %%
df = df.drop('latitude', axis=1)

# %%
df = df.drop('longitude', axis=1)

# %%
df = df.drop('ID', axis=1)

# %%
df = df.drop('data_moderator_initials', axis=1)

# %%
df = df.drop('source', axis=1)

# %%
df = df.drop('notes_for_discussion', axis=1)

# %%
df = df.drop('sequence_available', axis=1)

# %%
df = df.drop('additional_information', axis=1)

# %%
for col in df:
    if df.dtypes[col] == "object":
        df[col] = df[col].str.lower()

# %%
def parse_outcome(outcome):
    if isinstance(outcome, float):
        return "recovered"
    else:
        dead = ["died", "deceased", "death", "dead"]
        hospital = ["receiving treatment", "under treatment", "hospitalized",
                    "symptoms only improved with cough. currently hospitalized for follow-up.",
                    "treated in an intensive care unit (14.02.2020)", "stable condition", "stable",
                    "critical condition, intubated as of 14.02.2020", "severe", "critical condition", "severe illness",
                    "unstable", "migrated", "migrated_other"]
        recovered = ["alive", "discharge", "discharged from hospital", "recovering at home 03.03.2020",
                     "not hospitalized", "released from quarantine", "https://www.mspbs.gov.py/covid-19.php",
                     "discharged"]

        if outcome in dead:
            return "death"
        if outcome in hospital:
            return "hospitalized"
        if outcome in recovered:
            return "recovered"
    return outcome


df["outcome"].apply(parse_outcome).value_counts()
# Out:
# outcome
# recovered       2466865
# hospitalized     203447
# death              5999
# Name: count, dtype: int64

# %%
df["outcome"] = df["outcome"].apply(parse_outcome)

# %%
df["country"] = df["country"].fillna(df["country"].mode()[0])

# %%
def get_province(row):
    if row["province"].value_counts().empty:
        return float('NaN')
    else:
        return row["province"].value_counts().idxmax()

df["province"] = df["province"].fillna(df.groupby('country').apply(get_province, include_groups=False))

# %%
# Clean age field
def age_to_int(age_str):
    if isinstance(age_str, float):
        return None

    if "-" in age_str:
        age_min, age_max = age_str.split("-")
        if age_min == '':
            return int(age_max)
        if age_max == '':
            return int(age_min)
        age_min, age_max = int(age_min), int(age_max)
        return int((age_min + age_max) / 2)

    if "weeks" in age_str:
        return 0

    if "months" in age_str or "month" in age_str:
        num, _ = age_str.split(" ")
        if int(num) < 12:
            return 0
        return int(int(num) / 12)

    if age_str[-1] == "+" or age_str[-1] == "-":
        return int(age_str[:-1])

    return int(float(age_str))


df["age"] = df["age"].apply(age_to_int)
df["age"] = df["age"].fillna(int(df["age"].mean()))

# %%
def parse_bool(x):
    return not isinstance(x, float)

# %%
df["chronic_disease_binary"] = df["chronic_disease_binary"].apply(parse_bool)

# %%
df["lives_in_Wuhan"] = df["lives_in_Wuhan"].apply(parse_bool)

# %%
df["travel_history_binary"] = df["travel_history_binary"].apply(parse_bool)

# %%
df["reported_market_exposure"] = df["reported_market_exposure"].apply(parse_bool)

# %%
def parse_asymptomatic(x):
    return isinstance(x, float)

df["asymptomatic"] = df["date_onset_symptoms"].apply(parse_bool)

# %%
df.info(verbose=True, max_cols=307382, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676311 entries, 0 to 2676310
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   age                       2676311 non-null  float64
#  1   sex                       580157 non-null   object
#  2   city                      1698630 non-null  object
#  3   province                  2223647 non-null  object
#  4   country                   2676311 non-null  object
#  5   geo_resolution            2676250 non-null  object
#  6   date_onset_symptoms       261599 non-null   object
#  7   date_admission_hospital   116211 non-null   object
#  8   date_confirmation         2567822 non-null  object
#  9   symptoms                  2052 non-null     object
#  10  lives_in_Wuhan            2676311 non-null  bool
#  11  travel_history_dates      2611 non-null     object
#  12  travel_history_location   9222 non-null     object
#  13  reported_market_exposure  2676311 non-null  bool
#  14  chronic_disease_binary    2676311 non-null  bool
#  15  chronic_disease           215 non-null      object
#  16  outcome                   2676311 non-null  object
#  17  date_death_or_discharge   3148 non-null     object
#  18  location                  13376 non-null    object
#  19  admin3                    80434 non-null    object
#  20  admin2                    826054 non-null   object
#  21  admin1                    1257558 non-null  object
#  22  country_new               2645758 non-null  object
#  23  admin_id                  2676250 non-null  float64
#  24  travel_history_binary     2676311 non-null  bool
#  25  asymptomatic              2676311 non-null  bool
# dtypes: bool(5), float64(2), object(19)
# memory usage: 441.6+ MB

# %%
df['date_confirmation'] = pd.to_datetime(df['date_confirmation'], format='%d.%m.%Y', errors='coerce')

# %%
df['days_since_subject_zero'] = df["date_confirmation"].apply(lambda d: (d - datetime.datetime.strptime("17.11.2019", '%d.%m.%Y')).days)

# %%
df["outcome_binary"] = df['outcome'].apply(lambda x: 0 if x not in ["recovered", "hospitalized"] else 1)

# %%
df["hospitalized_binary"] = df['outcome'].apply(lambda x: 1 if x in ["hospitalized"] else 0)

# %%
df["death_binary"] = df['outcome'].apply(lambda x: 0 if x in ["recovered", "hospitalized"] else 1)

# %%
df
# Out:
#           age     sex            city          province    country  \
# 0        45.0    male        shek lei         hong kong      china
# 1        78.0    male      vo euganeo            veneto      italy
# 2        61.0  female             NaN               NaN  singapore
# 3        45.0     NaN  zhengzhou city             henan      china
# 4        45.0     NaN  pingxiang city           jiangxi      china
# ...       ...     ...             ...               ...        ...
# 2676306  52.0  female        calleria  coronel portillo       peru
# 2676307  52.0  female    pueblo libre              lima       peru
# 2676308  52.0  female           comas              lima       peru
# 2676309  52.0    male          callao            callao       peru
# 2676310  52.0    male      los olivos              lima       peru
#
#         geo_resolution date_onset_symptoms date_admission_hospital  \
# 0                point                 NaN                     NaN
# 1                point                 NaN                     NaN
# 2               admin0                 NaN                     NaN
# 3               admin2                 NaN                     NaN
# 4               admin2                 NaN                     NaN
# ...                ...                 ...                     ...
# 2676306          point                 NaN                     NaN
# 2676307          point                 NaN                     NaN
# 2676308          point                 NaN                     NaN
# 2676309          point                 NaN                     NaN
# 2676310          point                 NaN                     NaN
#
#         date_confirmation symptoms  ...          admin2     admin1  \
# 0              2020-02-14      NaN  ...             NaN  hong kong
# 1              2020-02-21      NaN  ...             NaN     veneto
# 2              2020-02-14      NaN  ...             NaN        NaN
# 3              2020-01-26      NaN  ...  zhengzhou city      henan
# 4              2020-02-14      NaN  ...  pingxiang city    jiangxi
# ...                   ...      ...  ...             ...        ...
# 2676306        2020-05-17      NaN  ...             NaN        NaN
# 2676307        2020-05-17      NaN  ...             NaN        NaN
# 2676308        2020-05-17      NaN  ...             NaN        NaN
# 2676309        2020-05-17      NaN  ...             NaN        NaN
# 2676310        2020-05-17      NaN  ...             NaN        NaN
#
#         country_new  admin_id  travel_history_binary asymptomatic  \
# 0             china    8029.0                  False        False
# 1             italy    8954.0                  False        False
# 2         singapore     200.0                  False        False
# 3             china   10091.0                  False        False
# 4             china    7060.0                  False        False
# ...             ...       ...                    ...          ...
# 2676306        peru   14429.0                   True        False
# 2676307        peru   14695.0                   True        False
# 2676308        peru   14400.0                   True        False
# 2676309        peru   14516.0                   True        False
# 2676310        peru   14502.0                   True        False
#
#         days_since_subject_zero outcome_binary hospitalized_binary  \
# 0                          89.0              1                   1
# 1                          96.0              0                   0
# 2                          89.0              1                   0
# 3                          70.0              1                   0
# 4                          89.0              1                   0
# ...                         ...            ...                 ...
# 2676306                   182.0              1                   0
# 2676307                   182.0              1                   0
# 2676308                   182.0              1                   0
# 2676309                   182.0              1                   0
# 2676310                   182.0              1                   0
#
#         death_binary
# 0                  0
# 1                  1
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 2676306            0
# 2676307            0
# 2676308            0
# 2676309            0
# 2676310            0
#
# [2676311 rows x 30 columns]

# %% [markdown]
# # Correlation Part 1A

# %%
def is_correlated(var_name1, var_name2, data_frame: pd.DataFrame):
    try:
        new_frame = data_frame[[var_name1, var_name2]]
        new_frame = new_frame.dropna(how="any", axis=0)
        ct = pd.crosstab(index=new_frame[var_name1], columns=new_frame[var_name2])
        print(ct)
        chi2_res = chi2_contingency(ct, )
        p, x, dof_ = chi2_res[1], "correlated" if chi2_res[1] < 0.05 else "not-correlated", chi2_res[2]
        return p, x, dof_
    except ValueError:
        return 0, "no data", 0

# %%
outcome_df = df[df['outcome'].notna()]

# %%
corr = [[], []]
to_check = ["sex", "country", "age", "lives_in_Wuhan", "travel_history_binary"]
for var1 in df:
    if var1 != "ID" and var1 in to_check:
        p_val, correlation, dof = is_correlated(var1, "outcome", outcome_df)
        if correlation == "correlated":
            corr[0].append((p_val, dof, var1))
        else:
            corr[1].append((p_val, dof, var1))
        print("")

corr[0].sort()
corr[1].sort()

print("Correlated")

for ln in corr[0]:
    print(ln)

print("Non-Correlated")

for ln in corr[1]:
    print(ln)
# Out:
# outcome  death  hospitalized  recovered
# age
# 0.0          6            33       1747
# 1.0         11           146        927
# 2.0          0           151       2584
# 3.0          0           153        725
# 4.0          0           131       1068
# ...        ...           ...        ...
# 105.0        0             0          6
# 106.0        0             0          1
# 107.0        0             0          1
# 120.0        0             0          4
# 121.0        0             0          1
#
# [110 rows x 3 columns]
#
# outcome  death  hospitalized  recovered
# sex
# female     546         10788     261635
# male       941         20586     285661
#
# outcome               death  hospitalized  recovered
# country
# afghanistan               0             0          8
# albania                   0             0       1054
# algeria                   7             0       1260
# andorra                   0             0          1
# angola                    0             0          4
# ...                     ...           ...        ...
# venezuela                 0             0          2
# vietnam                   0             0         34
# virgin islands, u.s.      0             0          2
# zambia                    0             0         22
# zimbabwe                  4            31          1
#
# [146 rows x 3 columns]
#
# outcome         death  hospitalized  recovered
# lives_in_Wuhan
# False            5954        203433    2462586
# True               45            14       4279
#
# outcome                death  hospitalized  recovered
# travel_history_binary
# False                     81            82      65416
# True                    5918        203365    2401449
#
# Correlated
# (0.0, 2, 'sex')
# (0.0, 2, 'travel_history_binary')
# (0.0, 218, 'age')
# (0.0, 290, 'country')
# (1.3254731626810238e-98, 2, 'lives_in_Wuhan')
# Non-Correlated

# %% [markdown]
# # MCA
# Here we will use MCA instead of PCA in order to produce visualizations for discrete variables

# %%
import prince
from sklearn.preprocessing import LabelEncoder

# %%
continuous_dataset = df[["outcome_binary", "age", "travel_history_binary", "days_since_subject_zero", "asymptomatic", "lives_in_Wuhan"]]
continuous_dataset =  continuous_dataset.dropna(how="any", axis=0).sample(n=5000, random_state=42)
continuous_dataset.corr()
# Out:
#                          outcome_binary       age  travel_history_binary  \
# outcome_binary                 1.000000 -0.012900              -0.006045
# age                           -0.012900  1.000000               0.003018
# travel_history_binary         -0.006045  0.003018               1.000000
# days_since_subject_zero       -0.032273 -0.080521               0.377955
# asymptomatic                  -0.003426  0.026092               0.029831
# lives_in_Wuhan                 0.001402  0.016733              -0.129943
#
#                          days_since_subject_zero  asymptomatic  lives_in_Wuhan
# outcome_binary                         -0.032273     -0.003426        0.001402
# age                                    -0.080521      0.026092        0.016733
# travel_history_binary                   0.377955      0.029831       -0.129943
# days_since_subject_zero                 1.000000     -0.109739       -0.075885
# asymptomatic                           -0.109739      1.000000        0.037113
# lives_in_Wuhan                         -0.075885      0.037113        1.000000

# %%
continuous_dataset.info(verbose=True, max_cols=307382, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 2387036 to 931788
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   outcome_binary           5000 non-null   int64
#  1   age                      5000 non-null   float64
#  2   travel_history_binary    5000 non-null   bool
#  3   days_since_subject_zero  5000 non-null   float64
#  4   asymptomatic             5000 non-null   bool
#  5   lives_in_Wuhan           5000 non-null   bool
# dtypes: bool(3), float64(2), int64(1)
# memory usage: 170.9 KB

# %%
pca = prince.PCA(
    n_components=1000,
    n_iter=5,
    copy=True,
    check_input=True,
    random_state=42,
    engine="sklearn" # same parameter as sklearn.preprocessing.OneHotEncoder
)
pca = pca.fit(continuous_dataset)
pca.eigenvalues_summary
# Out:
#           eigenvalue % of variance % of variance (cumulative)
# component
# 0              1.447        24.12%                     24.12%
# 1              1.042        17.36%                     41.48%
# 2              1.001        16.68%                     58.16%
# 3              0.979        16.31%                     74.46%
# 4              0.947        15.79%                     90.25%
# 5              0.585         9.75%                    100.00%

# %%
pca.plot(
    continuous_dataset,
    x_component=0,
    y_component=1
)
# Out:
# alt.LayerChart(...)

# %%
pca.column_contributions_.head().style.format('{:.0%}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_63a2a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >component</th>
#       <th id="T_63a2a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_63a2a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_63a2a_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_63a2a_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_63a2a_level0_col4" class="col_heading level0 col4" >4</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63a2a_level0_row0" class="row_heading level0 row0" >outcome_binary</th>
#       <td id="T_63a2a_row0_col0" class="data row0 col0" >0%</td>
#       <td id="T_63a2a_row0_col1" class="data row0 col1" >7%</td>
#       <td id="T_63a2a_row0_col2" class="data row0 col2" >81%</td>
#       <td id="T_63a2a_row0_col3" class="data row0 col3" >11%</td>
#       <td id="T_63a2a_row0_col4" class="data row0 col4" >0%</td>
#     </tr>
#     <tr>
#       <th id="T_63a2a_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_63a2a_row1_col0" class="data row1 col0" >2%</td>
#       <td id="T_63a2a_row1_col1" class="data row1 col1" >36%</td>
#       <td id="T_63a2a_row1_col2" class="data row1 col2" >2%</td>
#       <td id="T_63a2a_row1_col3" class="data row1 col3" >59%</td>
#       <td id="T_63a2a_row1_col4" class="data row1 col4" >2%</td>
#     </tr>
#     <tr>
#       <th id="T_63a2a_level0_row2" class="row_heading level0 row2" >travel_history_binary</th>
#       <td id="T_63a2a_row2_col0" class="data row2 col0" >44%</td>
#       <td id="T_63a2a_row2_col1" class="data row2 col1" >9%</td>
#       <td id="T_63a2a_row2_col2" class="data row2 col2" >3%</td>
#       <td id="T_63a2a_row2_col3" class="data row2 col3" >0%</td>
#       <td id="T_63a2a_row2_col4" class="data row2 col4" >44%</td>
#     </tr>
#     <tr>
#       <th id="T_63a2a_level0_row3" class="row_heading level0 row3" >days_since_subject_zero</th>
#       <td id="T_63a2a_row3_col0" class="data row3 col0" >51%</td>
#       <td id="T_63a2a_row3_col1" class="data row3 col1" >0%</td>
#       <td id="T_63a2a_row3_col2" class="data row3 col2" >0%</td>
#       <td id="T_63a2a_row3_col3" class="data row3 col3" >0%</td>
#       <td id="T_63a2a_row3_col4" class="data row3 col4" >49%</td>
#     </tr>
#     <tr>
#       <th id="T_63a2a_level0_row4" class="row_heading level0 row4" >asymptomatic</th>
#       <td id="T_63a2a_row4_col0" class="data row4 col0" >2%</td>
#       <td id="T_63a2a_row4_col1" class="data row4 col1" >48%</td>
#       <td id="T_63a2a_row4_col2" class="data row4 col2" >15%</td>
#       <td id="T_63a2a_row4_col3" class="data row4 col3" >30%</td>
#       <td id="T_63a2a_row4_col4" class="data row4 col4" >5%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #

# %% [markdown]
# # Part 2: Bayes Net
